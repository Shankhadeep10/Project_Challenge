# %% [markdown]
# # 1.Import required libraries and read the dataset.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 2.Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
data=pd.read_csv(r"C:\Users\shank\Downloads\honeyproduction (3).csv")
data.head(5)
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
data.shape
# Out:
# (626, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.3+ KB

# %%
data.describe()
# Out:
#               numcol  yieldpercol     totalprod        stocks  priceperlb  \
# count     626.000000   626.000000  6.260000e+02  6.260000e+02  626.000000
# mean    60284.345048    62.009585  4.169086e+06  1.318859e+06    1.409569
# std     91077.087231    19.458754  6.883847e+06  2.272964e+06    0.638599
# min      2000.000000    19.000000  8.400000e+04  8.000000e+03    0.490000
# 25%      9000.000000    48.000000  4.750000e+05  1.430000e+05    0.932500
# 50%     26000.000000    60.000000  1.533000e+06  4.395000e+05    1.360000
# 75%     63750.000000    74.000000  4.175250e+06  1.489500e+06    1.680000
# max    510000.000000   136.000000  4.641000e+07  1.380000e+07    4.150000
#
#           prodvalue         year
# count  6.260000e+02   626.000000
# mean   4.715741e+06  2004.864217
# std    7.976110e+06     4.317306
# min    1.620000e+05  1998.000000
# 25%    7.592500e+05  2001.000000
# 50%    1.841500e+06  2005.000000
# 75%    4.703250e+06  2009.000000
# ...

# %% [markdown]
# # 3.Display the percentage distribution of the data in each year using the pie chart.

# %%
data['year'].unique()
# Out:
# array([1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#        2009, 2010, 2011, 2012], dtype=int64)

# %%
plt.pie(data['year'].value_counts(),autopct="%.2f%%",radius=1.1,labels=data['year'].unique())
plt.title('distribution of the data in each year')
plt.show()

# %% [markdown]
# # 4.Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
plt.figure(figsize=(8,8))
sns.distplot(data['priceperlb'])
plt.xlabel("priceperlb")
plt.ylabel("density")
plt.title("distribution of the variable (price per lb) using displot")
# Out:
# C:\Users\shank\AppData\Local\Temp\ipykernel_12060\538925502.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['priceperlb'])
# Text(0.5, 1.0, 'distribution of the variable (price per lb) using displot')

# %% [markdown]
# It is positive skew curb here data distribution has longer or fatter on the right side. In this priceperlb data are cummulatively distributed and frequency data present in 1 and 2 bin size.In this curb mean is greater then median and median is greater then mode.And outlier also present on right side.

# %% [markdown]
# # 5.Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings.

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(data,x="numcol",y="prodvalue",color="green")
plt.xlabel=("numcol")
plt.ylabel=("Prodvalue")
plt.title=("numcol vs prodvalue scatterplot")

# %% [markdown]
# In this scatter plot I have seen the relationship between column 'numcol' and column 'prodval'.In this scatter plot have
# positive relationship between eachothers.Because here prodvalue and numcol value both are increasing together so its a positive relationship.

# %% [markdown]
# # 6.Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue' through boxplot, and write your findings.

# %%
plt.figure(figsize=(8,8))
sns.boxplot(data,x='year',y='prodvalue')
plt.title=("Relationship between year and prodvalue boxplot")

# %% [markdown]
# Here I have drawn a boxplot in one categorical variable column 'year' and one numerical column 'prodvalue'.Here the boxplot
# displaying the prodvalue data distirbution fro each years.And the boxplot represent the interquartile range(IQR) of the data.It is median marked inside the box.Whiskers show extend  the range of the data and those data are beyond from whiskers
# these are the may outliers.In this boxplot the year 2002 have a extream outliers as compair the others columns.Outliers that indicates the unsual or extream value fro each years.If the median is vary significant that it suggest that the potential relationship between prodvalue and year columns.Here years(2010,2011,2012) has very stong relationship between prodvalue.

# %% [markdown]
# # 7.Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')

# %%
sns.pairplot(data,vars=['numcol','yieldpercol','totalprod','prodvalue'],hue="year")

# %% [markdown]
# In this pairplot I have mapping the year wise multiple pair of variables.Here I see that years of 2000 and 2002 in column 'numcol' data are distributed in positive skew.It means more of tha data has distributed longer or fatter on the right side
# and there mean>median>mode and data frequency is much more high as compair to others.Column 'numcol',and column 'totalprod' having reprsent the scatterplot and in this plot both data are positive correlated eachother because both are increase and also column 'numcol' and column 'prodvalue' it is also same.In the years(2010,2012) data are cummulatively distributed and data represent normal distribution curb  but in the scatterplot column 'prodvalue' and col 'numcol' their have positive correlationship but data have outliesr.Its means there some data are unusual or errors in data.

# %% [markdown]
# # 8.Display the correlation values using a plot and add your inferences. (use columns 'numcol','yield percol','total prod','stocks','price per lb','prodvalue')

# %%
sns.heatmap(data[['numcol','yieldpercol','totalprod','stocks','priceperlb','prodvalue']].corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# In this correlation plot represented the different colors it is showing the positive and negative relationship between each
# variables.here black colors boxs are represent the negative relationsip means there have no relationship between two variables.Its means these are statistically insignificant.And the orange colors boxs are represent the storng positive
# correlationship between them.In this plot totalprod and yieldprecol have positive correlation its means one variable increase and others variable also be increase as well.But here priceperlb and stocks have negative correlation between its means one variable might be increase and other variables tends to be decrease.Priceperlb and prodvalue have weak correlation between then it is vary close to 'zero' its means there have non-linear relationship.
